# %%
#where i get the dataset : https://forexsb.com/historical-forex-data

# %%
pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf
file = 'XAUUSD_M5.csv'
df = pd.read_csv(file)


#splitting date column and drop unnamed column
df[['Date', 'Time']] = df['Date'].str.split(' ', 1, expand=True)

#create a table with new column (Time)
df = df[['Date','Time','Open', 'High', 'Low','Close','Volume']]
df
# Out:
# C:\Users\zanma\AppData\Local\Temp\ipykernel_4028\2993881299.py:9: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Date', 'Time']] = df['Date'].str.split(' ', 1, expand=True)
#              Date   Time      Open      High       Low     Close  Volume
# 0      2022-04-29  12:50  1909.408  1909.408  1907.498  1907.973       5
# 1      2022-04-29  12:55  1907.973  1911.098  1907.798  1910.815       5
# 2      2022-04-29  13:00  1910.815  1913.288  1909.258  1912.908       5
# 3      2022-04-29  13:05  1912.888  1913.458  1911.988  1912.128       5
# 4      2022-04-29  13:10  1912.127  1912.238  1909.398  1909.448       5
# ...           ...    ...       ...       ...       ...       ...     ...
# 99995  2023-09-26  10:35  1913.275  1913.295  1912.578  1912.615       5
# 99996  2023-09-26  10:40  1912.595  1912.635  1912.275  1912.415       5
# ...

# %%
#start_date = '2023-05-01'
#end_date = '2023-09-10'
#x = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
#x

#get certain date



def visualize(when):
    certain_date = df[df['Date'] == when]
    certain_date
    
    #get certain time
    start_time = '10:00'
    end_time = '15:00'
    certain_datetime = certain_date[(certain_date['Time'] >= start_time) & (certain_date['Time'] <= end_time)]
    certain_datetime
    
    #candlestick
    certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
    certain_datetime.set_index('Time', inplace=True) # Set the 'Date' column as index
    mpf.plot(certain_datetime, type='candle', style='classic', title='Chart', ylabel='level') # Create a candlestick chart

# %%
visualize('2022-07-08')
visualize('2022-07-15')
visualize('2022-07-22')
visualize('2022-07-29')
visualize('2022-08-05')
visualize('2022-08-12')
visualize('2022-08-19')
visualize('2022-08-26')
visualize('2022-09-02')
visualize('2022-09-09')
visualize('2022-09-16')
visualize('2022-09-23')
visualize('2022-09-30')
visualize('2022-10-07')
visualize('2022-10-14')
visualize('2022-10-21')
visualize('2022-10-28')
visualize('2022-11-04')
visualize('2022-11-11')
visualize('2022-11-18')
visualize('2022-11-25')
visualize('2022-12-02')
visualize('2022-12-09')
visualize('2022-12-16')
visualize('2022-12-23')
visualize('2022-12-30')
visualize('2023-01-06')
visualize('2023-01-13')
visualize('2023-01-20')
visualize('2023-01-27')
visualize('2023-02-03')
visualize('2023-02-10')
visualize('2023-02-17')
visualize('2023-02-24')
visualize('2023-03-03')
visualize('2023-03-10')
visualize('2023-03-17')
visualize('2023-03-24')
visualize('2023-03-31')
visualize('2023-04-07')
visualize('2023-04-14')
visualize('2023-04-21')
visualize('2023-04-28')
visualize('2023-05-05')
visualize('2023-05-12')
visualize('2023-05-19')
visualize('2023-05-26')
visualize('2023-06-02')
visualize('2023-06-09')
visualize('2023-06-16')
visualize('2023-06-23')
visualize('2023-06-30')
visualize('2023-07-07')
visualize('2023-07-14')
visualize('2023-07-21')
visualize('2023-07-28')
visualize('2023-08-04')
visualize('2023-08-11')
visualize('2023-08-18')
visualize('2023-08-25')
visualize('2023-09-01')
visualize('2023-09-08')
visualize('2023-09-15')
visualize('2023-09-22')
# Out:
# C:\Users\zanma\AppData\Local\Temp\ipykernel_4028\2159883437.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
# C:\Users\zanma\AppData\Local\Temp\ipykernel_4028\2159883437.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
# ...
